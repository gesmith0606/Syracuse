# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen

# %%
url = 'https://finviz.com/screener.ashx?v=161&f=idx_sp500'
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
website = urlopen(req).read()
html = soup(website, 'html.parser')

# %%
# View the initial data in html format 
tables= pd.read_html(str(html))
table= tables[-2]
tables
# Out:
# [                                                   0   1   2
#  0  if(document.body.clientWidth>1500){document.wr... NaN NaN
#  1                                                NaN NaN NaN,
#                                                    0     1         2     3   \
#  0  if(document.body.clientWidth>1500){document.wr...   NaN       NaN   NaN
#  1                                               Home  News  Screener  Maps
#
#         4          5        6        7      8       9          10     11  12  \
#  0     NaN        NaN      NaN      NaN    NaN     NaN        NaN    NaN NaN
#  1  Groups  Portfolio  Insider  Futures  Forex  Crypto  Backtests  Elite NaN
#
#     13    14     15        16
#  0 NaN   NaN    NaN       NaN
#  1 NaN  Help  Login  Register  ,
#                                                    0   \
#  0  My Presets -Save Screen -Edit Screens Order: T...
#  1  Filters: 1  Descriptive(1) Fundamental Technic...
#  2  Exchange AnyAMEXNASDAQNYSECustom (Elite only) ...
# ...

# %%
# See if we can select the table we need 
table.columns = table.iloc[0]
table = table[1:]
table
# Out:
# 0  No. Ticker Market Cap Dividend     ROA      ROE     ROI Curr R Quick R  \
# 1    1      A     41.06B    0.61%  11.50%   23.70%  14.70%   2.20    1.60
# 2    2    AAL     10.74B        -  -2.90%   26.20%  -1.60%   0.90    0.80
# 3    3    AAP     12.72B    1.92%   5.20%   18.80%  15.60%   1.20    0.30
# 4    4   AAPL   2621.23B    0.55%  28.70%  149.80%  50.00%   1.00    1.00
# 5    5   ABBV    280.51B    3.56%   7.70%   83.00%  17.90%   0.80    0.70
# 6    6    ABC     31.83B    1.21%   3.00%        -  24.30%   0.90    0.60
# 7    7   ABMD     14.00B        -   8.80%    9.80%  12.50%   7.00    6.30
# 8    8    ABT    213.73B    1.55%   9.60%   20.60%  13.50%   1.80    1.50
# 9    9    ACN    210.34B    1.21%  14.70%   32.00%  29.90%   1.20    1.20
# 10  10   ADBE    209.60B        -  18.60%   34.10%  26.00%   1.30    1.30
# 11  11    ADI     83.72B    1.73%   3.50%    5.10%   3.40%   2.10    1.60
# 12  12    ADM     47.10B    1.77%   5.10%   12.50%   6.60%   1.50    0.80
# ...

# %%
# Scrape all 505 tickers that are in the S & P 500 with their corresponding Financial information 
# first 20 records 
url = f'https://finviz.com/screener.ashx?v=161&f=idx_sp500$'
req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
website = urlopen(req).read()
html = soup(website, 'html.parser')
tables= pd.read_html(str(html))
table= tables[-2]
table.columns = table.iloc[0]
table = table[1:]

# %%
# records 21 - 40 

url2=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=21'
req2 = Request(url2, headers={'User-Agent': 'Mozilla/5.0'})
website2 = urlopen(req2).read()
html2 = soup(website2, 'html.parser')
tables2= pd.read_html(str(html2))
table2= tables2[-2]
table2.columns = table2.iloc[0]
table2 = table2[1:]

# %%
# 41 - 60 
url3=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=41'
req3 = Request(url3, headers={'User-Agent': 'Mozilla/5.0'})
website3 = urlopen(req3).read()
html3 = soup(website3, 'html.parser')
tables3= pd.read_html(str(html3))
table3= tables3[-2]
table3.columns = table3.iloc[0]
table3 = table3[1:]

# %%
# 61 - 80 
url4=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=61'
req4 = Request(url4, headers={'User-Agent': 'Mozilla/5.0'})
website4 = urlopen(req4).read()
html4 = soup(website4, 'html.parser')
tables4= pd.read_html(str(html4))
table4= tables4[-2]
table4.columns = table4.iloc[0]
table4 = table4[1:]

# %%
# 81 - 100
url5=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=81'
req5 = Request(url5, headers={'User-Agent': 'Mozilla/5.0'})
website5 = urlopen(req5).read()
html5 = soup(website5, 'html.parser')
tables5= pd.read_html(str(html5))
table5= tables5[-2]
table5.columns = table5.iloc[0]
table5 = table5[1:]

# %%
# 101 - 120 
url6=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=101'
req6 = Request(url6, headers={'User-Agent': 'Mozilla/5.0'})
website6 = urlopen(req6).read()
html6 = soup(website6, 'html.parser')
tables6= pd.read_html(str(html6))
table6= tables6[-2]
table6.columns = table6.iloc[0]
table6 = table6[1:]

# %%
# 121 - 140 
url7=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=121'
req7 = Request(url7, headers={'User-Agent': 'Mozilla/5.0'})
website7 = urlopen(req7).read()
html7 = soup(website7, 'html.parser')
tables7 = pd.read_html(str(html7))
table7= tables7[-2]
table7.columns = table7.iloc[0]
table7 = table7[1:]

# %%
# 141 - 160 
url8=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=141'
req8 = Request(url8, headers={'User-Agent': 'Mozilla/5.0'})
website8 = urlopen(req8).read()
html8 = soup(website8, 'html.parser')
tables8 = pd.read_html(str(html8))
table8= tables8[-2]
table8.columns = table8.iloc[0]
table8 = table8[1:]

# %%
# 161 - 180 
url9=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=161'
req9 = Request(url9, headers={'User-Agent': 'Mozilla/5.0'})
website9 = urlopen(req9).read()
html9 = soup(website9, 'html.parser')
tables9 = pd.read_html(str(html9))
table9= tables9[-2]
table9.columns = table9.iloc[0]
table9 = table9[1:]

# %%
# 181 - 200 
url10=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=181'
req10 = Request(url10, headers={'User-Agent': 'Mozilla/5.0'})
website10 = urlopen(req10).read()
html10 = soup(website10, 'html.parser')
tables10 = pd.read_html(str(html10))
table10= tables10[-2]
table10.columns = table10.iloc[0]
table10 = table10[1:]

# %%
# 201 - 220
url11=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=201'
req11 = Request(url11, headers={'User-Agent': 'Mozilla/5.0'})
website11 = urlopen(req11).read()
html11 = soup(website11, 'html.parser')
tables11 = pd.read_html(str(html11))
table11= tables11[-2]
table11.columns = table11.iloc[0]
table11 = table11[1:]

# %%
# 221 - 240
url12=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=221'
req12 = Request(url12, headers={'User-Agent': 'Mozilla/5.0'})
website12 = urlopen(req12).read()
html12 = soup(website12, 'html.parser')
tables12 = pd.read_html(str(html12))
table12= tables12[-2]
table12.columns = table12.iloc[0]
table12 = table12[1:]

# %%
# 241 - 260
url13=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=241'
req13 = Request(url13, headers={'User-Agent': 'Mozilla/5.0'})
website13 = urlopen(req13).read()
html13 = soup(website13, 'html.parser')
tables13 = pd.read_html(str(html13))
table13= tables13[-2]
table13.columns = table13.iloc[0]
table13 = table13[1:]

# %%
# 261 - 280
url14=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=261'
req14 = Request(url14, headers={'User-Agent': 'Mozilla/5.0'})
website14 = urlopen(req14).read()
html14 = soup(website14, 'html.parser')
tables14 = pd.read_html(str(html14))
table14= tables14[-2]
table14.columns = table14.iloc[0]
table14 = table14[1:]

# %%
# 281 - 300
url15=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=281'
req15 = Request(url15, headers={'User-Agent': 'Mozilla/5.0'})
website15 = urlopen(req15).read()
html15 = soup(website15, 'html.parser')
tables15 = pd.read_html(str(html15))
table15= tables15[-2]
table15.columns = table15.iloc[0]
table15 = table15[1:]

# %%
#301 - 320 
url16=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=301'
req16 = Request(url16, headers={'User-Agent': 'Mozilla/5.0'})
website16 = urlopen(req16).read()
html16 = soup(website16, 'html.parser')
tables16 = pd.read_html(str(html16))
table16= tables16[-2]
table16.columns = table16.iloc[0]
table16 = table16[1:]

# %%
#321 - 340 
url17=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=321'
req17 = Request(url17, headers={'User-Agent': 'Mozilla/5.0'})
website17 = urlopen(req17).read()
html17 = soup(website17, 'html.parser')
tables17 = pd.read_html(str(html17))
table17= tables17[-2]
table17.columns = table17.iloc[0]
table17 = table17[1:]

# %%
#321 - 340 
url17=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=321'
req17 = Request(url17, headers={'User-Agent': 'Mozilla/5.0'})
website17 = urlopen(req17).read()
html17 = soup(website17, 'html.parser')
tables17 = pd.read_html(str(html17))
table17= tables17[-2]
table17.columns = table17.iloc[0]
table17 = table17[1:]

# %%
#341 - 360 
url18=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=341'
req18 = Request(url18, headers={'User-Agent': 'Mozilla/5.0'})
website18 = urlopen(req18).read()
html18 = soup(website18, 'html.parser')
tables18 = pd.read_html(str(html18))
table18= tables18[-2]
table18.columns = table18.iloc[0]
table18 = table18[1:]

# %%
#361 - 380 
url19=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=361'
req19 = Request(url19, headers={'User-Agent': 'Mozilla/5.0'})
website19 = urlopen(req19).read()
html19 = soup(website19, 'html.parser')
tables19 = pd.read_html(str(html19))
table19= tables19[-2]
table19.columns = table19.iloc[0]
table19 = table19[1:]

# %%
#381 - 400 
url20=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=381'
req20 = Request(url20, headers={'User-Agent': 'Mozilla/5.0'})
website20 = urlopen(req20).read()
html20 = soup(website20, 'html.parser')
tables20 = pd.read_html(str(html20))
table20= tables20[-2]
table20.columns = table20.iloc[0]
table20 = table20[1:]

# %%
#401 - 420
url21=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=401'
req21 = Request(url21, headers={'User-Agent': 'Mozilla/5.0'})
website21 = urlopen(req21).read()
html21 = soup(website21, 'html.parser')
tables21 = pd.read_html(str(html21))
table21= tables21[-2]
table21.columns = table21.iloc[0]
table21 = table21[1:]

# %%
#421 - 440
url22=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=421'
req22 = Request(url22, headers={'User-Agent': 'Mozilla/5.0'})
website22 = urlopen(req22).read()
html22 = soup(website22, 'html.parser')
tables22 = pd.read_html(str(html22))
table22= tables22[-2]
table22.columns = table22.iloc[0]
table22 = table22[1:]

# %%
#441 - 460
url23=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=441'
req23 = Request(url23, headers={'User-Agent': 'Mozilla/5.0'})
website23 = urlopen(req23).read()
html23 = soup(website23, 'html.parser')
tables23 = pd.read_html(str(html23))
table23= tables23[-2]
table23.columns = table23.iloc[0]
table23 = table23[1:]

# %%
#461 - 480
url24=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=461'
req24 = Request(url24, headers={'User-Agent': 'Mozilla/5.0'})
website24 = urlopen(req24).read()
html24 = soup(website24, 'html.parser')
tables24 = pd.read_html(str(html24))
table24= tables24[-2]
table24.columns = table24.iloc[0]
table24 = table24[1:]

# %%
#481 - 500
url25=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=481'
req25 = Request(url25, headers={'User-Agent': 'Mozilla/5.0'})
website25 = urlopen(req25).read()
html25 = soup(website25, 'html.parser')
tables25 = pd.read_html(str(html25))
table25= tables25[-2]
table25.columns = table25.iloc[0]
table25 = table25[1:]

# %%
#501 - 505
url26=f'https://finviz.com/screener.ashx?v=161&f=idx_sp500&r=501'
req26 = Request(url26, headers={'User-Agent': 'Mozilla/5.0'})
website26 = urlopen(req26).read()
html26 = soup(website26, 'html.parser')
tables26 = pd.read_html(str(html26))
table26= tables26[-2]
table26.columns = table26.iloc[0]
table26 = table26[1:]

# %%
# Combine all data into 1 data frame 
tables = pd.concat([table, table2,table3,table4,table5,table6,table7,table8,table9,table10,table11,table12,table13,
                   table14,table15,table16,table17,table18,table19,table20,table21,table22,table23,table24,table25,table26])

# %%
# view tables dataframe 
tables.head(25)
# Out:
# 0  No. Ticker Market Cap Dividend       ROA       ROE      ROI Curr R Quick R  \
# 1    1      A     41.06B    0.61%    11.50%    23.70%   14.70%   2.20    1.60
# 2    2     AA     14.97B    0.50%     2.90%    11.00%    5.00%   1.60    1.00
# 3    3   AAAU          -        -         -         -        -      -       -
# 4    4    AAC      1.22B        -     1.60%     1.70%        -   0.40    0.40
# 5    5   AACG     43.15M        -   -17.50%   -49.20%  -48.20%   0.30    0.30
# 6    6   AACI    203.99M        -         -         -        -   0.40    0.40
# 7    7  AACIW          -        -         -         -        -      -       -
# 8    8   AADI    407.15M        -  -134.90%  -147.00%  -14.70%  14.00   14.00
# 9    9   AADR          -    0.29%         -         -        -      -       -
# 10  10   AAIC    106.97M        -    -1.40%    -6.40%   -1.30%      -       -
# 11  11    AAL     10.74B        -    -2.90%    26.20%   -1.60%   0.90    0.80
# ...

# %%
tables.tail(25)
# Out:
# 0   No. Ticker Market Cap Dividend     ROA      ROE     ROI Curr R Quick R  \
# 1   481    WAT     20.02B        -  22.10%  238.50%  37.60%   2.40    1.90
# 2   482    WBA     40.99B    4.02%   7.10%   27.70%   4.60%   0.80    0.40
# 3   483    WDC     15.29B        -   7.70%   18.10%   5.70%   1.90    1.20
# 4   484    WEC     30.22B    3.04%   3.40%   12.00%   5.60%   0.70    0.50
# 5   485   WELL     41.16B    2.65%   1.00%    2.00%   2.00%      -       -
# 6   486    WFC    196.37B    1.55%   1.00%   12.00%  10.50%      -       -
# 7   487    WHR     11.43B    3.58%   8.80%   37.60%  18.00%   1.10    0.80
# 8   488     WM     64.52B    1.67%   6.30%   25.00%  10.80%   0.80    0.70
# 9   489    WMB     38.33B    5.20%   3.30%   13.30%   6.00%   0.90    0.80
# 10  490    WMT    402.24B    1.54%   4.10%   12.50%   5.80%   0.90    0.30
# 11  491    WRB     16.84B    0.55%   3.30%   15.60%  11.60%      -       -
# ...

# %%
# check that all the data has made it into the final dataframe 
tables.size
print('Size of dataframe =',tables.size)
print('Shape of dataframe =',tables.shape)
# Out:
# Size of dataframe = 9090
# Shape of dataframe = (505, 18)

# %%
# export data frame 
tables.to_csv("finvizscraped.csv")

# %%
# read in saved data frame as beautiful soup will keep updating the data 
sandp = pd.read_csv('finvizscraped.csv')
sandp.head()
# Out:
#    Unnamed: 0  No. Ticker Market Cap  Dividend   ROA   ROE   ROI  Curr R  \
# 0           1    1      A     41.06B      0.01  0.12  0.24  0.15     2.2
# 1           2    2     AA     14.97B      0.01  0.03  0.11  0.05     1.6
# 2           3    3   AAAU        NaN       NaN   NaN   NaN   NaN     NaN
# 3           4    4    AAC      1.22B       NaN  0.02  0.02   NaN     0.4
# 4           5    5   AACG     43.15M       NaN  0.18  0.49  0.48     0.3
#
#    Quick R  LTDebt/Eq  Debt/Eq  Gross M  Oper M  Profit M   Price  Change  \
# 0      1.6       0.53     0.00     0.54    0.22      0.19  136.82    0.01
# 1      1.0       0.37     0.37     0.25    0.08      0.04   80.73    0.07
# 2      NaN        NaN      NaN      NaN     NaN       NaN   19.26    0.00
# 3      0.4       0.00     0.00      NaN     NaN       NaN    9.76    0.00
# 4      0.3       0.00     0.00     0.47    0.53      0.51    1.38    0.06
#
#     Volume
# 0  1163313
# 1  8420623
# 2   617732
# 3    31136
# 4    37654

# %%
# Taiwan data set starts here 

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# read taiwan data 
data = pd.read_csv("data.csv")
data.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.heatmap(data.corr())
plt.show()

# %%
tables.head()
# Out:
# 0 No. Ticker Market Cap Dividend      ROA      ROE      ROI Curr R Quick R  \
# 1   1      A     41.06B    0.61%   11.50%   23.70%   14.70%   2.20    1.60
# 2   2     AA     14.97B    0.50%    2.90%   11.00%    5.00%   1.60    1.00
# 3   3   AAAU          -        -        -        -        -      -       -
# 4   4    AAC      1.22B        -    1.60%    1.70%        -   0.40    0.40
# 5   5   AACG     43.15M        -  -17.50%  -49.20%  -48.20%   0.30    0.30
#
# 0 LTDebt/Eq Debt/Eq Gross M   Oper M Profit M  Earnings   Price  Change  \
# 1      0.53    0.00  54.00%   21.60%   18.70%  Feb 22/a  136.82   1.35%
# 2      0.37    0.37  24.70%    7.80%    3.50%  Jan 19/a   80.73   6.74%
# 3         -       -       -        -        -         -   19.26   0.47%
# 4      0.00    0.00       -        -        -         -    9.76  -0.10%
# 5      0.00    0.00  46.60%  -53.20%  -50.50%  Mar 17/a    1.38   6.15%
#
# 0   Volume
# 1  1163313
# 2  8420623
# 3   617732
# 4    31136
# 5    37654

# %%
# Drop the columns we will not be needing 
data.drop(' ROA(A) before interest and % after tax',
             ' ROA(B) before interest and depreciation after tax',
                                     ' Pre-tax net Interest Rate',
                                   ' After-tax net Interest Rate',
                   ' Non-industry income and expenditure/revenue',
                          ' Continuous interest rate (after tax)',
                                        ' Operating Expense Rate',
                         ' Research and development expense rate',
                                                ' Cash flow rate',
                           ' Interest-bearing debt interest rate',
                                                  ' Tax rate (A)',
                                       ' Net Value Per Share (B)',
                                       ' Net Value Per Share (A)',
                                       ' Net Value Per Share (C)',
                       ' Persistent EPS in the Last Four Seasons',
                                           ' Cash Flow Per Share',
                                    ' Revenue Per Share (Yuan ¥)',
                           ' Operating Profit Per Share (Yuan ¥)',
                      ' Per Share Net profit before tax (Yuan ¥)',
                       ' Realized Sales Gross Profit Growth Rate',
                                  ' Operating Profit Growth Rate',
                                                    'Unnamed: 26',
                                ' Regular Net Profit Growth Rate',
                             ' Continuous Net Profit Growth Rate',
                                       ' Total Asset Growth Rate',
                                         ' Net Value Growth Rate',
                          ' Total Asset Return Growth Rate Ratio',
                                           ' Cash Reinvestment %',
                                                 ' Current Ratio',
                                                   ' Quick Ratio',
                                        ' Interest Expense Ratio',
                                    ' Total debt/Total net worth',
                                                  ' Debt ratio %',
                                              ' Net worth/Assets',
                          ' Long-term fund suitability ratio (A)',
                                          ' Borrowing dependency',
                              ' Contingent liabilities/Net worth',
                              ' Operating profit/Paid-in capital',
                         ' Net profit before tax/Paid-in capital',
                   ' Inventory and accounts receivable/Net value',
                                          ' Total Asset Turnover',
                                  ' Accounts Receivable Turnover',
                                       ' Average Collection Days',
                               ' Inventory Turnover Rate (times)',
                               ' Fixed Assets Turnover Frequency',
                               ' Net Worth Turnover Rate (times)',
                                            ' Revenue per person',
                                   ' Operating profit per person',
                                    ' Allocation rate per person',
                               ' Working Capital to Total Assets',
                                     ' Quick Assets/Total Assets',
                                   ' Current Assets/Total Assets',
                                             ' Cash/Total Assets',
                                ' Quick Assets/Current Liability',
                                        ' Cash/Current Liability',
                                   ' Current Liability to Assets',
                                  ' Operating Funds to Liability',
                                     ' Inventory/Working Capital',
                                   ' Inventory/Current Liability',
                                 ' Current Liabilities/Liability',
                                        ' Working Capital/Equity',
                                    ' Current Liabilities/Equity',
                         ' Long-term Liability to Current Assets',
                             ' Retained Earnings to Total Assets',
                                    ' Total income/Total expense',
                                          ' Total expense/Assets',
                                   ' Current Asset Turnover Rate',
                                     ' Quick Asset Turnover Rate',
                                ' Working capitcal Turnover Rate',
                                            ' Cash Turnover Rate',
                                            ' Cash Flow to Sales',
                                        ' Fixed Assets to Assets',
                                ' Current Liability to Liability',
                                     ' Cash Flow to Total Assets',
                                        ' Cash Flow to Liability',
                                                 ' CFO to Assets',
                                           ' Cash Flow to Equity',
                           ' Current Liability to Current Assets',
                                         ' Liability-Assets Flag',
                                    ' Net Income to Total Assets',
                                     ' Total assets to GNP price',
                                            ' No-credit Interval',
                                         ' Gross Profit to Sales',
                            " Net Income to Stockholder's Equity",
                                           ' Liability to Equity',
                            ' Degree of Financial Leverage (DFL)',
            ' Interest Coverage Ratio (Interest expense to EBIT)',
                                               ' Net Income Flag',
                                           ' Equity to Liability',
                                                       'Bankrupt',
                                                                )

# %%
# create two similar data sets to predict bankrupcy 
Taiwan = pd.read_csv("Taiwan.csv")
Bankrupt = Taiwan[Taiwan['Bankrupt?']== 0]
Bankrupt.head()
# Out:
#     Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 6           0                                           0.390923
# 7           0                                           0.508361
# 8           0                                           0.488519
# 9           0                                           0.495686
# 10          0                                           0.482475
#
#      Operating Gross Margin   Operating Profit Rate   Current Ratio  \
# 6                  0.619950                0.998993        0.004672
# 7                  0.601738                0.999009        0.009657
# 8                  0.603612                0.998961        0.013499
# 9                  0.599209                0.999001        0.011475
# 10                 0.614026                0.998978        0.006097
#
#      Quick Ratio   Long-term Liability to Current Assets  \
# 6       0.002869                                0.009347
# ...

# %%
Bankrupt[[' ROA(C) before interest and depreciation before interest']].mean()
# Out:
#  ROA(C) before interest and depreciation before interest    0.508069
# dtype: float64

# %%
Bankrupt[[' ROA(C) before interest and depreciation before interest']].plot()
# Out:
# <AxesSubplot:>

# %%
Bankrupt[[' Operating Gross Margin']].mean()
# Out:
#  Operating Gross Margin    0.608257
# dtype: float64

# %%
Bankrupt[[' Operating Gross Margin']].plot()
# Out:
# <AxesSubplot:>

# %%
Bankrupt[[' Current Ratio']].mean()
# Out:
#  Current Ratio    416729.822913
# dtype: float64

# %%
Bankrupt[[' Current Ratio']].plot()
# Out:
# <AxesSubplot:>

# %%
Bankrupt[[' Current Ratio']].max()
# Out:
#  Current Ratio    2.750000e+09
# dtype: float64

# %%
Bankrupt[[' Quick Ratio']].mean()
# Out:
#  Quick Ratio    7.257160e+06
# dtype: float64

# %%
Bankrupt[[' Quick Ratio']].plot()
# Out:
# <AxesSubplot:>

# %%
Bankrupt[[' Quick Ratio']].max()
# Out:
#  Quick Ratio    8.920000e+09
# dtype: float64

# %%
Bankrupt[[' Liability to Equity']].mean()
# Out:
#  Liability to Equity    0.279925
# dtype: float64

# %%
Bankrupt[[' Liability to Equity']].plot()
# Out:
# <AxesSubplot:>

# %%
print(tables.columns)
# Out:
# Index(['No.', 'Ticker', 'Market Cap', 'Dividend', 'ROA', 'ROE', 'ROI',
#        'Curr R', 'Quick R', 'LTDebt/Eq', 'Debt/Eq', 'Gross M', 'Oper M',
#        'Profit M', 'Earnings', 'Price', 'Change', 'Volume'],
#       dtype='object', name=0)

# %%
tables.head()
# Out:
# 0 No. Ticker Market Cap Dividend      ROA      ROE      ROI Curr R Quick R  \
# 1   1      A     41.06B    0.61%   11.50%   23.70%   14.70%   2.20    1.60
# 2   2     AA     14.97B    0.50%    2.90%   11.00%    5.00%   1.60    1.00
# 3   3   AAAU          -        -        -        -        -      -       -
# 4   4    AAC      1.22B        -    1.60%    1.70%        -   0.40    0.40
# 5   5   AACG     43.15M        -  -17.50%  -49.20%  -48.20%   0.30    0.30
#
# 0 LTDebt/Eq Debt/Eq Gross M   Oper M Profit M  Earnings   Price  Change  \
# 1      0.53    0.00  54.00%   21.60%   18.70%  Feb 22/a  136.82   1.35%
# 2      0.37    0.37  24.70%    7.80%    3.50%  Jan 19/a   80.73   6.74%
# 3         -       -       -        -        -         -   19.26   0.47%
# 4      0.00    0.00       -        -        -         -    9.76  -0.10%
# 5      0.00    0.00  46.60%  -53.20%  -50.50%  Mar 17/a    1.38   6.15%
#
# 0   Volume
# 1  1163313
# 2  8420623
# 3   617732
# 4    31136
# 5    37654

# %%
sandp.head()
# Out:
#    Unnamed: 0  No. Ticker Market Cap Dividend    ROA    ROE    ROI Curr R  \
# 0           1    1      A     41.06B     0.01   0.12   0.24   0.15   2.20
# 1           2    2     AA     14.97B     0.01   0.03   0.11   0.05   1.60
# 2           3    3   AAAU          -        -      -      -      -      -
# 3           4    4    AAC      1.22B        -   0.02   0.02      -   0.40
# 4           5    5   AACG     43.15M        -  -0.18  -0.49  -0.48   0.30
#
#   Quick R LTDebt/Eq Debt/Eq Gross M Oper M Profit M   Price  Change     Volume
# 0    1.60      0.53    0.00    0.54   0.22     0.19  136.82    0.01  1163313.0
# 1    1.00      0.37    0.37    0.25   0.08     0.04   80.73    0.07  8420623.0
# 2       -         -       -       -      -        -   19.26    0.00   617732.0
# 3    0.40      0.00    0.00       -      -        -    9.76    0.00    31136.0
# 4    0.30      0.00    0.00    0.47  -0.53    -0.51    1.38    0.06    37654.0

# %%
# drop NA in the sandp data 
sandp.dropna()
# Out:
#      Unnamed: 0  No. Ticker Market Cap  Dividend   ROA   ROE   ROI  Curr R  \
# 0             1    1      A     41.06B      0.01  0.12  0.24  0.15     2.2
# 1             2    2     AA     14.97B      0.01  0.03  0.11  0.05     1.6
# 14           15   15   AAON      2.95B      0.01  0.11  0.15  0.12     2.5
# 15           16   16    AAP     12.72B      0.02  0.05  0.19  0.16     1.2
# 16           17   17   AAPL   2621.23B      0.01  0.29  1.50  0.50     1.0
# ..          ...  ...    ...        ...       ...   ...   ...   ...     ...
# 497          18  498    XOM    334.37B      0.04  0.07  0.14  0.07     1.0
# 498          19  499   XRAY     10.61B      0.01  0.05  0.08  0.07     1.5
# 499          20  500    XYL     15.85B      0.01  0.05  0.14  0.09     2.3
# 501           2  502    ZBH     25.58B      0.01  0.02  0.03  0.03     1.4
# 504           5  505    ZTS     91.41B      0.01  0.15  0.46  0.18     3.9
#
# ...

# %%
# convert to numeric 
sandp['ROA'] = pd.to_numeric(sandp['ROA'])

# %%
sandp['ROA'].plot()
# Out:
# <AxesSubplot:>

# %%
sandp['Oper M'].plot()
# Out:
# <AxesSubplot:>

# %%
sandp['Oper M'].max()
# Out:
# 1.0

# %%
sandp['Oper M'].mean()
# Out:
# 0.2133333333333333

# %%
sandp['Curr R'].max()
# Out:
# 14.0

# %%
sandp['Curr R'].mean()
# Out:
# 1.686063569682151

# %%
sandp['Curr R'].plot()
# Out:
# <AxesSubplot:>

# %%
sandp['Quick R'].max()
# Out:
# 14.0

# %%
sandp['Quick R'].plot()
# Out:
# <AxesSubplot:>

# %%
sandp['Debt/Eq'].plot()
# Out:
# <AxesSubplot:>

# %%
sandp500=sandp[['Ticker','ROA']]
sandp500.dropna
sandp500.head()
# Out:
#   Ticker      ROA
# 0      A   11.50%
# 1     AA    2.90%
# 2   AAAU        -
# 3    AAC    1.60%
# 4   AACG  -17.50%

# %%
#sandp500['ROA']=sandp500['ROA'].astype('Categories')

# %%
#ROA = sandp500['ROA'].between(.49,.51, inclusive = True)

# %%
print(sandp500.dtypes)
# Out:
# Ticker    object
# ROA       object
# dtype: object

# %%
# Logistic Regression model

# %%
x = data.drop('Bankrupt?', axis=1)
y = data['Bankrupt?']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 10)

# %%
model = LogisticRegression(max_iter = 7000)

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(max_iter=7000)

# %%
from sklearn.metrics import confusion_matrix,classification_report
from mlxtend.plotting import plot_confusion_matrix

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
y_predict = model.predict(x_test)
confusion_matrix_model = confusion_matrix(y_test,y_predict)
print(confusion_matrix_model)
print(f'rows mean Actual , columns mean Predicted')
# Out:
# [[1639    6]
#  [  60    0]]
# rows mean Actual , columns mean Predicted

# %%
fig, ax = plot_confusion_matrix(conf_mat=confusion_matrix_model, figsize=(6, 6), cmap=plt.cm.Greens)
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=25 , pad=15)

plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score

# %%
print("Classification Report",classification_report(y_test,y_predict))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      1645
#            1       0.00      0.00      0.00        60
#
#     accuracy                           0.96      1705
#    macro avg       0.48      0.50      0.49      1705
# weighted avg       0.93      0.96      0.95      1705

# %%
print("accuracy of Logistic Regression model :", accuracy_score(y_test,y_predict))
# Out:
# accuracy of Logistic Regression model : 0.9612903225806452

# %%
# Random Forest Model 
# train test and split the data 
X = data.drop('Bankrupt?', axis=1)
y = data['Bankrupt?']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Random Forest Model 
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Making predictions using the testing data Random Forest 
predictions = rf_model.predict(X_test_scaled)

# %%
# Calculating the confusion matrix
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Display Predictions 
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0         1644            3
# Actual 1           49            9
# Accuracy Score : 0.9695014662756598
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      1647
#            1       0.75      0.16      0.26        58
#
#     accuracy                           0.97      1705
#    macro avg       0.86      0.58      0.62      1705
# weighted avg       0.96      0.97      0.96      1705

# %%
importances = rf_model.feature_importances_

sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.03460675623935172, " Net Income to Stockholder's Equity"),
#  (0.028546157225539957, ' Borrowing dependency'),
#  (0.0263439175460734, ' Net profit before tax/Paid-in capital'),
#  (0.0218642452403669, ' Net Income to Total Assets'),
#  (0.021105658420614962, ' Degree of Financial Leverage (DFL)'),
#  (0.02092196024184578, ' Persistent EPS in the Last Four Seasons'),
#  (0.02074130879113118, ' Net worth/Assets'),
#  (0.020690036912912026, ' Interest Expense Ratio'),
#  (0.020672597957360317, ' Net Value Per Share (A)'),
#  (0.02056309994108588, ' Non-industry income and expenditure/revenue'),
#  (0.019914062457478704, ' Liability to Equity'),
#  (0.019524084298126937, ' Per Share Net profit before tax (Yuan ¥)'),
#  (0.01944616819892758, ' Net Value Per Share (B)'),
#  (0.01916152618140112, ' Cash/Total Assets'),
#  (0.018480231507311227, ' Equity to Liability'),
#  (0.018037920630713973, ' ROA(A) before interest and % after tax'),
#  (0.017849667864857414, ' Debt ratio %'),
# ...
