# %%
import tweepy
import json
import sys
from twitter_login_fn import oauth_login
from twitter_login_fn import appauth_login
from DB_fn import save_to_DB
from DB_fn import load_from_DB


api = appauth_login()
for tweet in tweepy.Cursor(api.search_tweets, q='Covid').items(10):
    print(tweet.text)
# Out:
# RT @fiannabradley: @RedJohnBounds No. Not moving on until Sasha @BorisJohnson and his cabinet/ex cabinet of vicious, talentless, sycophants…
# @Judson4America Who the hell does he think he is? POS! Scolding kids for choosing to wear masks, to not catch Covid… https://t.co/FZanoSBfbE
# RT @Neopseudo: @AlanBixter And what else would we expect, he’s made his disdain for science abundantly clear
# This is the bloke who brought…
# @leezeldin Lee Zeldin has caused more damage than Covid.
# RT @khwangreports: According to CDC numbers, half of the state lives in the highest tier for COVID risk—where masking should continue—but t…
# RT @antoniovaldezEC: NUEVO: @GovRonDeSantis molesto con los estudiantes de la USF.
#
#  "No tienen que usar esas máscaras. Por favor, quítense…
# @Estadao Putz...e eu que pensei que o covid tinha acabado nesse carnaval! Pelo visto ele voltou...
# El covid es com una grip, deien https://t.co/FF6KfSFJf2
# ...

# %%
for tweet in tweepy.Cursor(api.search_tweets, q='bitcoin').items(10):
    print(tweet.user.name,tweet.user.friends_count,tweet.user.followers_count, tweet.text)
    print()
# Out:
# Wokebeast 141 153 RT @bearishgatito: #Bitcoin https://t.co/jRFJyc0vX3
#
# Endoplazmikkul 3351 176 RT @coindoktorunuz: Bu Gönderiyi Fav - RT Eden 2 Takipçime 500 TL Totalde 1000 TL Hediye..⭐✅
#
# Yapmanız Gereken:
#
# -  @CryptoThoor hesabını…
#
# DAIRO D.T 100 51 @PeterSchiff #Bitcoin https://t.co/5MLnb6WbUu
#
# Cowboy 174 71 Reminder: Lana Del Rey's sister had a bitcoin cake at her babyshower https://t.co/We41IncSCa
#
# backgroundtürkiye 48 18 eBay gelecek ay Bitcoin ve kripto piyasasını sevindirecek adımı atar mı? https://t.co/i6Y2FARIXd https://t.co/JIIr3WSiYC
#
# taheri 139 53 @BluesparrowC @BSCGemsAlert @binance Would you like to see crypto and the forex market on a platform?
# BlueSparrow… https://t.co/yhrvfyOK8W
#
# Kelley Carter 23 0 RT @TheEliteCrypto: Welcome back $40K #Bitcoin Stay longer this time 😁
#
# るな 199 23 RT @DMM_Bitcoin: ／
# 6カ月連続キャンペーン第2弾🎊
# 🎉#フォローRTキャンペーン 🎉
# 1,000円分のAmazonギフト券を抽選で400名様にプレゼント😊
# ＼
#
# ■応募方法
# ①@DMM_Bitcoin をフォロー
# ②この投稿をリツイート
# 応募期間は3/31(木…
#
# ...

# %%
dir(tweet.user)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'follower_ids',
#  'followers',
#  'followers_count',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'list_memberships',
#  'list_ownerships',
#  'list_subscriptions',
#  'listed_count',
# ...
