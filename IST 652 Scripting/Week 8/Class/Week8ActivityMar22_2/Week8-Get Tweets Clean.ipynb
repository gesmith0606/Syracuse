# %%
import tweepy
import json
import sys
from twitter_login_fn import oauth_login
from twitter_login_fn import appauth_login
from DB_fn import save_to_DB
from DB_fn import load_from_DB


api = appauth_login()
for tweet in tweepy.Cursor(api.search_tweets, q='Covid').items(10):
    print(tweet.text)
# Out:
# RT @rhonda_harbison: @GOPChairwoman https://t.co/Qw5LP2TZDF
# Iowa Gov. Kim Reynolds abused COVID money, State Auditor Rob ...
# RT @BossBlunts1: *8.5% of vaccinated people in Pfizers #Covid study released today developed Autoimmune diseases.
# Thread 🧵(1 of 5) https:/…
# RT @SalomonJA: 1/ There's been much discussion on new CDC “COVID-19 community levels," anchored largely on predicted deaths.
# How high will…
# RT @CasaRosada: "Hoy Argentina exhibe los mayores porcentajes de vacunación entre países con más de 30 millones de habitantes. Debajo están…
# RT @drlizzieskinner: Taken on Sunday.
#
# Morrison tests COVID positive last night.
#
# Now everyone in these photos are at risk.
#
# This is why…
# RT @markgurman: Apple is upping Covid-19 testing for retail staff to twice per week — regardless of vaccination status. Was previously 1x p…
# RT @LauraMariaEste1: No lo verás en las noticias.
#
# En USA el #PeoplesConvoy llega a Missouri
#
# Reclaman eliminar todas las restricciones Cov…
# RT @GreggorHanzo: Cómo omicron llegó a estropear el plan del virus chino. (dirán que fueron las "vacunas" ) hasta el enviado de Rockefeller…
# RT @Danielsalcan88: Toda la comunidad internacional logro organizarse en solo días para enviar miles y miles de millones en armas para Ucra…
# RT @inas_md: Earlier today, my father passed away in the ICU from a severe COVID infection. Please wear a mask, get vaccinated and be kind…

# %%
for tweet in tweepy.Cursor(api.search_tweets, q='bitcoin').items(10):
    print(tweet.user.name,tweet.user.friends_count,tweet.user.followers_count, tweet.text)
    print()
# Out:
# RC-Mining 3902 1496 RT @Dennis_Porter_: #Bitcoin VS. Russian Ruble.
# Down over 98% in 5 years. https://t.co/z9T0tnnvFa
#
# Joan 481 72 RT @cryptobcncat: Los gobiernos y los bancos saben que no pueden impedirnos usar #Bitcoin y las criptos 😼
#
# #Bitcoin nació para cambiar el p…
#
# Ray61Smith 1214 1353 RT @miirabell_: Y’all ain’t ready for what is coming!!!
#
# So guys @Bitcasinoio will be making a huge announcement tonight at 7pm EAT
#
# The Wo…
#
# The last days of an empire 2418 1000 RT @publordhodl: #Bitcoin held on an exchange is not Bitcoin.  🍻😂
#
# Favoured Child 1919 182 RT @Robinzockt123: 🎉FREE #NFTGiveaway 🎉
#
# How to enter:
# ✅ RT + ❤️
# ✅ Follow
# ✅ Drop your #eth wallet
#
# 💢END AT 120 RT💢
#
# #NFTs
# #NFTGiveaway…
#
# nima 118 97 @ThePeoplesInves @BlueSparrowETH @TomsCryptoChat @Crypto4Winz Would you like to see crypto and the forex market on… https://t.co/475YjPPJgt
#
# Maximilian-Lex 1877 1878 Part of my work team in #Brazil, mid-March upon his return we continue to advance in our #NFT development project-… https://t.co/MOtdYw6pOb
#
# CB360G 132 26 @Astrones2 @ProjectXNodes right behind Bitcoin if green candle!  If $BTC dips, $PXT 2 Will still be green!
#
# 0x ⚡️⚡️ Foundational 001😂 2232 519 RT @Nebraskangooner: #Bitcoin pumped after NYC closed yesterday. I
#
# I wonder what happens today.
#
# LeoJPWin 2188 565 RT @cryptoandee: @RubixChain is gully decentralized, censorship resistant &amp; deflationary with a hard capped supply of 51.4 mil #RBT tokens.…

# %%
dir(tweet.user)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'contributors_enabled',
#  'created_at',
#  'default_profile',
#  'default_profile_image',
#  'description',
#  'entities',
#  'favourites_count',
#  'follow',
#  'follow_request_sent',
#  'follower_ids',
#  'followers',
#  'followers_count',
#  'following',
#  'friends',
#  'friends_count',
#  'geo_enabled',
#  'has_extended_profile',
#  'id',
#  'id_str',
#  'is_translation_enabled',
#  'is_translator',
#  'lang',
#  'list_memberships',
#  'list_ownerships',
#  'list_subscriptions',
#  'listed_count',
#  'lists',
#  'location',
#  'name',
#  'notifications',
#  'parse',
#  'parse_list',
#  'profile_background_color',
#  'profile_background_image_url',
#  'profile_background_image_url_https',
#  'profile_background_tile',
#  'profile_image_url',
#  'profile_image_url_https',
#  'profile_link_color',
#  'profile_sidebar_border_color',
#  'profile_sidebar_fill_color',
#  'profile_text_color',
#  'profile_use_background_image',
#  'protected',
#  'screen_name',
#  'statuses_count',
#  'time_zone',
#  'timeline',
#  'translator_type',
#  'unfollow',
#  'url',
#  'utc_offset',
#  'verified',
#  'withheld_in_countries']
